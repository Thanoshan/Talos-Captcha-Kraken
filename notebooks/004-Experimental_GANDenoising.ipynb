# %% [markdown]
# Training a stage 1 model to help remove noise from CAPTCHAs before being passed into the next stage of our system to solve CAPTCHAs. Uses the well-known pix2pix model architecture, however trained on a custom dataset generated by us.
#
# Pix2Pix Paper Citation:
#
# Isola, Phillip & Zhu, Jun-Yan & Zhou, Tinghui & Efros, Alexei. (2017). Image-to-Image Translation with Conditional Adversarial Networks. 5967-5976. 10.1109/CVPR.2017.632.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('pix2pix/')

# %%
# !pip install -r requirements.txt

# %%
# !python datasets/combine_A_and_B.py --fold_A /content/pix2pix/captchas/A --fold_B /content/pix2pix/captchas/B --fold_AB /content/drive/MyDrive/thanos_temp/captchas

# %%
# !python train.py --dataroot /content/drive/MyDrive/thanos_temp/captchas --name experimental_denoise3 --model pix2pix --direction AtoB --no_flip --display_id 0 --n_epochs 50 --n_epochs_decay 50 --batch_size 1 --checkpoints_dir /content/drive/MyDrive/thanos_temp/checkpoints
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: /content/drive/MyDrive/thanos_temp/checkpoints	[default: ./checkpoints]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/thanos_temp/captchas	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
# ...

# %%
# !python test.py --dataroot /content/drive/MyDrive/thanos_temp/captchas --name experimental_denoise3 --model pix2pix --direction AtoB --no_flip num_test 500 --checkpoints_dir /content/drive/MyDrive/thanos_temp/checkpoints --results_dir /content/drive/MyDrive/thanos_temp/checkpoints/results
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/MyDrive/thanos_temp/checkpoints	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/thanos_temp/captchas	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
# !zip -r /content/thanosChecks.zip /content/drive/MyDrive/thanos_temp/checkpoints
# Out:
# Scanning files
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/ (stored 0%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/ (stored 0%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/train_opt.txt (deflated 79%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/web/ (stored 0%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/web/images/ (stored 0%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/web/images/epoch001_real_A.png (deflated 0%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/web/images/epoch001_fake_B.png (deflated 0%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/web/images/epoch001_real_B.png (deflated 1%)
#   adding: content/drive/MyDrive/thanos_temp/checkpoints/experimental_denoise2/web/images/epoch002_real_A.png (deflated 0%)
# ...

# %%
from google.colab import files
try:
  files.download("/content/thanosChecks.zip")
except Exception as e:
  print(e)
